# %%
import numpy as np
import pandas as pd
import spacy
import re, random
from pathlib import Path
from tqdm import tqdm 

pd.set_option('max_rows', None)
pd.set_option('max_columns', None)

pd.set_option('display.max_colwidth', -1)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:11: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %% [markdown]
# ## BULDING NER MODELS FOR BANK SMS DATA

# %%
# Load the saved model and predict
output_dir=Path("/home/ec2-user/SageMaker/Bulk Sms Data/Ner_model_to_use_V12")
print("Loading from", output_dir)
ner_model = spacy.load(output_dir)
# Out:
# Loading from /home/ec2-user/SageMaker/Bulk Sms Data/Ner_model_to_use_V12

# %%
import json
with open("train_data_new_wema.json", "r") as read_file:
    TRAIN_DATA = json.load(read_file)

# %%
TRAIN_DATA[:5]
# Out:
# [['Wema Credit  NGN600.00  Acct No 024639  Desc.  NIP Kehinde Johnson Bakare Transfer from to KEHIN   Bal  884.37  23 05 2021 03 45',
#   {'entities': [[5, 11, 'TYPE'],
#     [13, 22, 'AMOUNT'],
#     [40, 96, 'DESCRIPTION'],
#     [112, 122, 'DATE'],
#     [99, 110, 'BALANCE']]}],
#  ['Wema Debit  NGN18,000.00  Acct No 024133  Desc.  ALAT NIP TRANSFER TO GTB Tr   Bal  171,368.72  31 05 2021 10 42',
#   {'entities': [[5, 10, 'TYPE'],
#     [12, 24, 'AMOUNT'],
#     [42, 76, 'DESCRIPTION'],
#     [96, 106, 'DATE'],
#     [79, 94, 'BALANCE']]}],
#  ['Wema Credit  NGN15,000.00  Acct No 024402  Desc.  ATM Trf on 25 05 2021@ADDAX PETROLEUM   Bal  15,055.78  25 05 2021 02 21',
#   {'entities': [[5, 11, 'TYPE'],
#     [13, 25, 'AMOUNT'],
#     [43, 87, 'DESCRIPTION'],
#     [106, 116, 'DATE'],
#     [90, 104, 'BALANCE']]}],
#  ['Wema Debit  NGN6,250.00  Acct No 024177  Desc.  POS Purchase on 03 06 2021@PAYCOM NIGERIA LIM   Bal  4,826.25  03 06 2021 07 38',
#   {'entities': [[5, 10, 'TYPE'],
#     [12, 23, 'AMOUNT'],
#     [41, 93, 'DESCRIPTION'],
#     [111, 121, 'DATE'],
#     [96, 109, 'BALANCE']]}],
#  ['Wema Credit  NGN5,000.00  Acct No 022780  Desc.  NIP DEBORAH BLESSING BOLAJI NIP/ussd/IFT114413266   Bal  5,848.27  23 05 2021 06 07',
#   {'entities': [[5, 11, 'TYPE'],
#     [13, 24, 'AMOUNT'],
#     [42, 98, 'DESCRIPTION'],
#     [116, 126, 'DATE'],
#     [101, 114, 'BALANCE']]}]]

# %% [markdown]
# ## Add labels, Train data based on annotations

# %%
ner = ner_model.get_pipe('ner')

# %%
for _, annotations in TRAIN_DATA:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])

# %%
other_pipes = [pipe for pipe in ner_model.pipe_names if pipe != 'ner']

# %%
# %%time
from spacy.training.example import Example
with ner_model.disable_pipes(*other_pipes): 
    optimizer = ner_model.resume_training()
    for itn in range(5):
        random.shuffle(TRAIN_DATA)
        losses = {}
        for text, annotations in TRAIN_DATA:
            doc = ner_model.make_doc(text)
            example =  Example.from_dict(doc, annotations)
            ner_model.update(
                [example],  # batch of annotations
                drop=0.4,  # dropout 
                sgd=optimizer,  # callable to update weights
                losses=losses)
    print(losses)
# Out:
# {'ner': 4.000334420342062}
# CPU times: user 4.27 s, sys: 5.59 ms, total: 4.27 s
# Wall time: 4.27 s

# %%
doc = ner_model(msgtxt[0])
spacy.displacy.render(doc, style='ent', jupyter=True) 
print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Acct 9282
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TYPE</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     N3,000.00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AMOUNT</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Desc TRANSFER FROM RICHARD JOHN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DESCRIPTION</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DT 25/MAY/21
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  22 50PM
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bal N1,244,944.03CR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BALANCE</span>
# </mark>
#     Help 070034335489    Dial 77008 for a loan</div></span>
# Entities [('CR', 'TYPE'), ('N3,000.00', 'AMOUNT'), ('Desc TRANSFER FROM RICHARD JOHN', 'DESCRIPTION'), ('DT 25/MAY/21', 'DATE'), ('Bal N1,244,944.03CR', 'BALANCE')]

# %% [markdown]
# ## Model Evaluation on out of sample data
# ### To see if model will generalize well.

# %%
import json
with open("test_data_new.json", "r") as read_file:
    TEST_DATA = json.load(read_file)

# %%
import spacy
from spacy.scorer import Scorer
from spacy.tokens import Doc
from spacy.training.example import Example


TEST_DATA

example = []
def evaluate(ner_model, examples):
    for input_, annot in examples:
        doc = ner_model.make_doc(input_)
        temp = Example.from_dict(doc, annot)
        example.append(temp)
    scores_model = ner_model.evaluate(example)
    #print scores that you want
    precision_model = scores_model["ents_p"]
    recall_model = scores_model["ents_r"]
    f_score_model = scores_model["ents_f"]
    scores_entities = scores_model["ents_per_type"]
    print(f'The precision of the model is {round(precision_model*100,2)}%')
    print(f'The recall of the model is {round(recall_model*100,2)}%')
    print(f'The f1 of the model is {round(f_score_model*100,2)}%')
    print(f'Score entities is {scores_entities}')
    return scores_model

# ner_model = spacy.load('en_core_web_sm') # for spaCy's pretrained use 'en_core_web_sm'
results = evaluate(ner_model, TEST_DATA)
# Out:
# The precision of the model is 94.57%
# The recall of the model is 96.13%
# The f1 of the model is 95.34%
# Score entities is {'TYPE': {'p': 1.0, 'r': 1.0, 'f': 1.0}, 'AMOUNT': {'p': 1.0, 'r': 1.0, 'f': 1.0}, 'DESCRIPTION': {'p': 0.8648648648648649, 'r': 0.8648648648648649, 'f': 0.8648648648648649}, 'DATE': {'p': 0.9166666666666666, 'r': 0.9428571428571428, 'f': 0.9295774647887323}, 'BALANCE': {'p': 0.9459459459459459, 'r': 1.0, 'f': 0.9722222222222222}}

# %% [markdown]
# # MAKING PREDICTIONS

# %%
# n=500skiprows=lambda i: i % n != 0
df=pd.read_csv("s3://aws-athena-query-results-101063123548-eu-west-1/Unsaved/2021/08/02/df700ad6-4373-41d7-9297-47c8ed092b99.csv",nrows=100000)

# %% [markdown]
# ### Seperate Transactional text from Non Transactions

# %%
def detect_message(row): # Function to loan
    if (bool(re.search(r'\b(?:.*[Cre]dit.*|.*[De]bit.*|.*[Aa][Cc][Cc].*|.*[Char]ged.*|.*[N]gn.*)\b', row["short_message"],  re.IGNORECASE)) == True): 
    #if (bool(re.search(r'\b(?:credit|credi|cr|crd)\b', row["short_message"],  re.IGNORECASE)) == True):
        return 'Trans'
    else:
        return 'Non_trans'
# applying get_message function
df['Message_Type']=pd.DataFrame({'detect_m' : df.apply(detect_message, axis=1)})

# %%
def get_trans(*args, **kwargs):
    data = df[df['Message_Type'] != 'Non_trans']
    return data[['encrypted_msisdn','source_addr','short_message']]

# %%
df_1=get_trans(df)
print(df_1.shape)
# Out:
# (94010, 3)

# %%
searchfor = ['created', 'successfully','convenience']
df = df[~df.short_message.str.contains('|'.join(searchfor))]

# %%
df=df.reset_index(drop=True)

# %%
def clean_text(line):
    line = str(line) 
    line = line.replace('\n', '    ')
    line = line.replace(':', ' ')
    #     line = line.replace(',', ' ')
    line = line.replace('\n\n', '   ')
    line = line.replace('\n\n\n', '   ')
    line = line.replace('&', ' ')
    line = line.replace('#', '')
    line = line.replace('x200B', ' ')
    line = line.replace('[', ' ')
    line = line.replace(']', ' ')
    line = line.replace('(', ' ')
    line = line.replace(')', ' ')
    line = line.replace('|',' ')
    line = line.replace(':-', '')
    line = line.replace('~', '')
    line = line.replace('~~', '')
    line = line.replace('-', ' ')
    line = line.replace('\\', '')
    line = line.replace('*', '')
    line = line.replace('§', ' ')
    line = line.replace('\r', '   ')
    line = line.replace(',COMM', ' ')
    line = line.replace('\r\n', '   ')
    #line = line.replace('@', ' ')
    return line

# %%
# df['Clean_message']=new_ds
df['clean_message']=df.apply(lambda x:clean_text(x['short_message']), axis = 1)

# %%
msgtxt=df['clean_message'].to_list()
pred_list = []
for i in range(len(msgtxt)):
    x = msgtxt[i]
    pred = ner_model(x)
    sv = [(ent.text, ent.label_) for ent in pred.ents]
    pred_list.append(sv)

# %%
label_dic = {'TYPE','AMOUNT','DESCRIPTION','BALANCE','DATE'}
from collections import Counter

# %%
for elem in pred_list[:10000]:
    ent_list=[]
    val_list = []
    length_list = []
    for val,ent in elem:
        ent_list.append(ent)
        val_list.append(val)
    counts = Counter(ent_list).most_common()
    for ent_count in counts:
        key,val  = ent_count
        if val>1:
            duplicate_key = key
            if duplicate_key =='DESCRIPTION':
                find_index = [index for index, element in enumerate(ent_list) if element == duplicate_key]
                for i in range(val):
                    length_list.append(len(val_list[find_index[i]]))
                maximum_len = max(length_list)
                index_of_max = length_list.index(maximum_len)
                get_dup_index = find_index[index_of_max]
                elem.pop(get_dup_index)
            elif duplicate_key =='AMOUNT':
                find_index = [index for index, element in enumerate(ent_list) if element == duplicate_key]
                if 'BALANCE' in ent_list:
                    for i in range(val):
                        length_list.append(len(val_list[find_index[i]]))
                        maximum_len = max(length_list)
                        index_of_max = length_list.index(maximum_len)
                        get_dup_index = find_index[index_of_max]
                        elem.pop(get_dup_index)
                else:
                    duplicate = find_index[-1]
                    balance = val_list[[duplicate][0]]
                    bal_tup = (balance,'BALANCE')
                    elem.append(bal_tup)
                    elem.pop(duplicate)
            elif duplicate_key == 'DATE':
                find_index = [index for index, element in enumerate(ent_list) if element == duplicate_key]
                check1 = ['BVN','88A','@','2011Q692/','2011P180/','2011P180/','OL','000087 ZENITHATM3','O.A.U']
                dup_index = [i if any(x in val_list[find_index[i]] for x in check1)  else i for i in range(val)]
#                 print(dup_index)
                get_dup_index = find_index[dup_index[1]]
                elem.pop(get_dup_index)
            elif duplicate_key == 'TYPE':
                find_index = [index for index, element in enumerate(ent_list) if element == duplicate_key]
                check2 = ['Campu','CS','DI','CE','DE','CH','C33','CS DEP']
                dup_index = [i if any(x in val_list[find_index[i]] for x in check2) else i for i in range(val)]
                get_dup_index = find_index[dup_index[1]]
                elem.pop(get_dup_index)
            elif duplicate_key == 'BALANCE':
                find_index = [index for index, element in enumerate(ent_list) if element == duplicate_key]
                check3 = ['B84APLL18334400','88A','BenueNG','FE9']
                dup_index = [i if any(x in val_list[find_index[i]] for x in check3) else i for i in range(val)]
                bal_str = val_list[find_index[dup_index[0]]]
                date = bal_str.replace('B84APLL18334400 ','')
                bal_tup = (date,'DATE')
                elem.append(bal_tup)
                get_dup_index = find_index[dup_index[0]]
                elem.pop(get_dup_index)
            else:
                pass

# %% [markdown]
# ### CONVERTING PREDICTIONS TO DATAFRAME

# %%
test = {}
for elem in pred_list[:420]:
    if len(elem) < 5:
        l = []
        for val in elem:
            ent,label = val
            l.append(label)
        msng_label = list(label_dic - set(l))
        for i in range(len(msng_label)):
            ent,label = ' ',msng_label[i]
            elem.append((ent,label))
#         print('_____')
            
    for match in elem:
        ent,label = match
        if label in test:
            test[label].append(ent)
        else:
#             print(ent)
            test[label] = [ent]

# %%
df_use=pd.DataFrame(test)

# %%
df_use['clean_message'] = df['clean_message'][:420]

# %%
df_use.head(100)
# Out:
#        TYPE            AMOUNT  \
# 0   CR       N3,000.00
# 1   DR       N1,000.00
# 2   DR       N8,850.00
# 3   CR       N55,000.00
# 4   DR       N4,850.00
# 5   DR       N2,000.00
# 6   CR       NGN6,500.00
# 7   DR       NGN11,000.00
# 8   CR       NGN5,500.00
# 9   DR       NGN900.00
# 10  Debit    NGN15,000.00
# 11  Credit   NGN100,000.00
# 12  Debit    NGN9,000.00
# 13  Debit    NGN20,500.00
# 14  Debit    NGN45,000.00
# 15  Debit    NGN20,000.00
# 16  Debit    NGN20,000.00
# 17  Debit    NGN20,000.00
# 18  Credit   NGN64,914.90
# 19  Credit   NGN14,000.00
# 20  Credit   NGN13,000.00
# 21  Credit   NGN15,000.00
# 22  DR       NGN500.00
# 23  DR       NGN3,500.00,
# 24  DR       NGN500.00
# 25  DR       NGN1,000.00,
# 26  DR       NGN100.00
# 27  DR       NGN500.00
# 28  CR       N3,000.00
# 29  DR       N3,000.00
# 30  CR       NGN10,000.00
# 31  DR       NGN100.00
# 32  DR       NGN100.00
# 33  CR       NGN1,000.00
# 34  DR       NGN100.00
# 35  Debit    Amt N12,000.00
# 36  Debit    Amt N6,500.00
# 37  Credit   Amt N62,356.87
# 38  Debit    Amt N600.00
# 39  Credit!  Amt N10,000.00
# 40  Debit!   Amt N 10.00
# 41  Debit!   Amt N 10,000.00
# 42
# 43  DR       NGN5,000.00
# 44  Debit    NGN45,000.00
# 45  Debit    NGN23,000.00
# 46
# 47
# 48  Debit    Amt N1,000.00
# 49  Credit   NGN1,500.00
# 50  Debit    NGN10,000.00
# 51  Debit    NGN1,000.00
# 52  Credit   NGN10,000.00
# 53  Credit   NGN9,291.53
# 54  Debit    NGN3,000.00
# 55  Debit    NGN5,000.00
# 56  Credit   NGN5,000.00
# 57  Credit   NGN12,000.00
# 58  Credit   Amt N1,000.00
# 59  Credit   Amt N3,000.00
# 60  Credit   Amt N700.00
# 61  Debit    Amt N73,000.00
# 62  Credit   Amt N700.00
# 63  Credit   Amt N70,000.00
# 64  Debit    Amt N7,000.00
# 65  DR       N600.00
# 66
# 67  DR       N510.00
# 68  DR
# 69  DR       N100.00
# 70  DR       N510.00
# 71  CR       NGN1,000.00
# 72  Credit   NGN300,000.00
# 73  Credit   NGN50,000.00
# 74  Credit   NGN320,000.00
# 75  Debit    NGN760,000.00
# 76  Credit   NGN700,000.00
# 77  Debit    NGN55,000.00
# 78  Credit   NGN36,000.00
# 79  Credit   NGN10,000.00
# 80  Debit    NGN5,000.00
# 81  Debit    NGN10,000.00
# 82  Debit    NGN1,000.00
# 83  Credit   NGN100,000.00
# 84  DR       NGN100.00
# 85  DR       NGN3,000.00
# 86  Credit   NGN3,000.00
# 87  Credit   NGN20,000.00
# 88  DR       NGN20,000.00
# 89  DR       NGN20,000.00
# 90  DR       NGN20,000.00
# 91  DR       NGN20,000.00
# 92  CR       NGN5,000.00
# 93  DR       NGN6,150.00
# 94  CR       NGN8,000.00
# 95  CR       NGN1,000.00
# 96  CR       NGN5,000.00
# 97  CR       NGN20,000.00
# 98  DR       NGN20,000.00
# 99  CR       NGN10,000.00
#
#                                                                        DESCRIPTION  \
# 0   Desc TRANSFER FROM RICHARD JOHN
# 1   Desc POS PURCHASE @2033UYY0 SOBAZ NIGERIA LIMITE
# 2   Desc POS PURCHASE @20637G89 WELLDONE SUPERMARKET
# 3   Desc FUNDSTRF FOR UGOCHI GLORY NWAOHA  9282
# 4   Desc POS PURCHASE @20637G89 WELLDONE SUPERMARKET
# 5   Desc POS PURCHASE @2076OM15 CHARLES CHIMEKA OPAR
# 6   Desc  RUTH KADIRI AIWUMUAGBONRIE/Tran
# 7   Desc  POS@2057CP84/AGLOW HOMEWARES        LA
# 8   Desc  RUTH KADIRI AIWUMUAGBONRIE/Tran
# 9   Desc  POS@2232475E/OPAY DIGITAL SERVICE
# 10  TRANSFER IFO Kelechi   Anabaraonye Interbank
# 11  NIP FROM DARLINGTON OBINNA OKAFOR/SOFT LOAN
# 12  TRANSFER IFO Kelechi   Anabaraonye Interbank
# 13  TRANSFER IFO Kelechi   Anabaraonye Interbank
# 14  NIP TRANSFER IFO SOMTOO CHUKWUBUEZE NWAFOR Interban
# 15  Desc.  ATM WD on 28 05 2021@SIJUWADE HOUSE PLO
# 16  Desc.  ATM WD on 28 05 2021@SIJUWADE HOUSE PLO
# 17  Desc.  ATM WD on 28 05 2021@SIJUWADE HOUSE PLO
# 18  Desc.   496264685/FGN  FEDER PENSIONPAYMENTFOR202105
# 19  NIP FROM SUNNY YOUNG NIG LTD/SPARE PARTS /000012/97
# 20  NIP FROM SUNNY YOUNG NIG LTD/SPARE PARTS /000012/98
# 21  NIP FROM SUNNY YOUNG NIG LTD/SPARE PARTS /000012/98
# 22  Desc  USSD/QT PYMT/Airtime Recharge on 2349036586685
# 23  Desc  USSD/UNION Transfer to IDEM NSIKAN UDO
# 24  Desc  USSD/QT PYMT/Airtime Recharge on 2348169160500
# 25  Desc  USSD/UNION Transfer to EUNICE CHINONSO AKUWUDIKE
# 26  Desc  USSD/QT PYMT/Airtime Recharge on 2348037626012
# 27  Desc  USSD/QT PYMT/Airtime Recharge on 2349036586685
# 28  Desc TRANSFER FROM BLESSING UKAMAKA OKEKE
# 29  Desc POS PURCHASE @2TEPLT81 T AKU VENTURES
# 30  Desc  FOLI AUGUSTA NNEBUOGOFOLI AUGUSTA NNEBUOGO/USSD NIP Transfer from
# 31  Desc  USSD/QT PYMT/Airtime Recharge on 2349032170930
# 32  Desc  USSD/QT PYMT/Airtime Recharge on 2349032170930
# 33  Desc  SUCCESS   EREKWDOR/Bills
# 34  Desc  POS@3IPG0001/MSPORT_t1140393642i3650interswitchdeLANG
# 35  Ref USSD.BNKG 058/ADEYEMI ASHOLA O/F
# 36  Ref USSD.BNKG 057/VICTORIA NSICAN BAS
# 37  Ref 25/05 Neft  GTB LASG PAYROLL AD
# 38  Ref USSD.BNKG 058/ADEYEMI ASHOLA O/FT TO  A
# 39  Desc UNIEDUSOKO14 NEFT TRF BO UNIED
# 40  Desc Charges
# 41  Desc TRF IFO MUHAMMAD JIBRIN TSONFA
# 42
# 43  Desc  PYA@2TEPDB59/T De Kings          004357 2TEPDB59 LANG
# 44  NIP TRANSFER IFO SPICE OF LAGOS Interbank  REF  751
# 45  NIP TRANSFER IFO IJEOMA MARGARET OKOLINTA Interbank
# 46
# 47
# 48  Ref 2232LG12 PATHFINDER MICROFINANCE O
# 49  NIP FROM ROBAN OLADIPUPO ALLYSON/OLA /100004/100504
# 50  Desc.  ATM WD on 25 05 2021@ELIZADE UNIVERSITY
# 51  Desc.  ATM WD on
# 52  Desc.  NIP POS Agent utavie pos utavie pos POS Trf for C
# 53  Desc.
# 54  Desc.  ATM WD on
# 55  Desc.  ATM WD on
# 56  NIP FROM URAMA OKWUDILI VALENTINE/770 TRANSFER FROM
# 57  NIP FROM NDUBUISI GABRIEL OSITA/WATER  /000015/0017
# 58  Ref NIBSS MUHAMMED  AKEEM ADEBAYOMUHA
# 59  Ref NIBSS SAKIRAT OLUWATOYIN OYEYEMI
# 60  Ref NIBSS MUHAMMED  AKEEM ADEBAYOMUHAMM
# 61  Ref 20017940 GIfelodu   Os
# 62  Ref NIBSS MUHAMMED  AKEEM ADEBAYOMUHAMM
# 63  Ref NIBSS ADESUYI FADEKE RACHAEL
# 64  Ref 2TEPEV32 183 2TEPEV32
# 65  Desc MTN 904 RECHARGE 08141192597 107000001189894
# 66
# 67  Desc 770 TRANSFER ROSEMARY NW 17 TO AMADI IJEOMA
# 68  Desc 770 TRANSFER TO STEPHEN HELEN UFOT 0429679062
# 69  Desc 770 RECHARGE FOR 08147325584 1016U21052101104
# 70  Desc 770 TRANSFER ROSEMARY NW 17 TO AMADI IJEOMA
# 71  Desc  UZOMA JEPHTHAH/REF748328946 BO UZOMA JEPHTHAH IFO ASHIBUOGWU CHI
# 72  Desc.  NIP OLADIMEJI ADEMOLA JOHN FBNMOBILE MORUFU ALABI
# 73  Desc.  NIP OLADIMEJI ADEMOLA JOHN FBNMOBILE MORUFU ALABI
# 74  Desc.  NIP OLADIMEJI ADEMOLA JOHN FBNMOBILE MORUFU ALABI
# 75  Desc.  TRSF TO OLADIMEJI ADEMOLA FRM OYEDELE MORUFU
# 76  Desc.  ALAT TRANSFER FROM ABUBAKR ABIOLA  ABUBAKR ABIOLA
# 77  Desc.  A CASH WDR BY MORUFU ALABI OYEDELE/12494590
# 78  Desc.  NIP Olamide Suliat Oladepo Transfer from to MORUF
# 79  Desc.  ALAT TRANSFER FROM ABUBAKR ABIOLA  ABUBAKR ABIOLA
# 80  Desc.  945 Transfer to STERLING RIDWAN OLALEYE ISIAKA
# 81  Desc.  945 Transfer to STERLING RIDWAN OLALEYE ISIAKA
# 82  Desc.  Data via USSD  To 9539070653823422021060220211837
# 83  Desc.  NIP OLADIMEJI ADEMOLA JOHN FBNMOBILE MORUFU ALABI
# 84  Desc  AFM@20078586/WT BEST STEVE GLOBAL ENTE       BENIN NG
# 85  Desc  PYA@20078586/WT BEST STEVE GLOBAL ENTE       BENIN NG
# 86  NIP FROM OGUWIKE CHIMAOBI AUGUSTUS/FBNMOBILE IBEKWE
# 87  NIP FROM OGUWIKE CHIMAOBI AUGUSTUS/FBNMOBILE IBEKWE
# 88  Desc  Cash Withdrawal from UBN ATM10326091@GBOGAN RD1 OSHOGBO     OSHOGBO
# 89  Desc  Cash Withdrawal from UBN ATM10326091@GBOGAN RD1 OSHOGBO     OSHOGBO
# 90  Desc  Cash Withdrawal from UBN ATM10326091@GBOGAN RD1 OSHOGBO     OSHOGBO
# 91  Desc  Cash Withdrawal from UBN ATM10326091@GBOGAN RD1 OSHOGBO     OSHOGBO
# 92  Desc  ADEDOTUN HAMMED ADEOYE/ONB TRF FROM ADEDOTUN H 2462 FBP
# 93  Desc  PYA@2TEPY252/T ABLELUX GLOBAL CO 010395 2TEPY252 LANG
# 94  Desc  OLAYEMI PETER BANKOLE/NIP/ussd/IFT114413266523643898267441533
# 95  Desc  KAZEEM ADEDAYOR OLANIPEKUN/MOB/UTO/8096342950/000018/Market
# 96  Desc  KEHINDE TAOFEEK ADISA/MOB/UTO/8096523612/000018/AbleGod
# 97  Desc  DANIEL CHUKWUEMEKA EBERE/Cana
# 98  Desc  Cash Withdrawal from UBN ATM10326091@GBOGAN RD1 OSHOGBO     OSHOGBO
# 99  Desc  ADELEKE SERIFDEEN ADEBOLA/App transfer To Union Bank ISRAEL OLUWATIMI
#
#                              DATE               BALANCE  \
# 0   DT 25/MAY/21                   Bal N1,244,944.03CR
# 1   DT 28/MAY/21                   Bal N1,243,940.03CR
# 2   DT 20/MAY/21                   Bal N1,242,001.78CR
# 3   DT 31/MAY/21                   Bal N1,292,082.03CR
# 4   DT 31/MAY/21                   Bal N1,237,086.03CR
# 5   DT 30/MAY/21                   Bal N1,241,936.03CR
# 6   DT                             Bal  NGN11,945.75CR
# 7   DT  26/MAY/2021                Bal  NGN945.75CR
# 8   DT                             Bal  NGN5,445.75CR
# 9   DT  26/MAY/2021                Bal  NGN1.75CR
# 10  21 May 21                      Bal NGN65,313.81
# 11  21 May 21                      Bal NGN100,840.69
# 12  29 May 21                      Bal NGN1,761.19
# 13  21 May 21                      Bal NGN80,340.69
# 14  24 May 21                      Bal NGN12,488.55
# 15  28 05 2021                     Bal  5,421.07
# 16  28 05 2021                     Bal  25,421.07
# 17  28 05 2021                     Bal  45,421.07
# 18  27 05 2021                     Bal  65,471.07
# 19  21 May 21                      Bal NGN69,507.11
# 20  27 May 21                      Bal NGN18,174.33
# 29  Acct 0572    DR N3,000.00    Desc POS PURCHASE @2TEPLT81 T AKU VENTURES      00    DT 20/MAY/21 16 00PM    Bal N1,495.78CR    Help 070034335489    Dial 77008 for a loan
# 30  Acct  8602    CR  NGN10,000.00    Desc  FOLI AUGUSTA NNEBUOGOFOLI AUGUSTA NNEBUOGO/USSD NIP Transfer from  08    DT  22/MAY/2021 16 39 02    Available Bal  NGN42,886.18CR
# 31  Acct  7204    DR  NGN100.00    Desc  USSD/QT PYMT/Airtime Recharge on 2349032170930    DT  24/MAY/2021 06 26 55    Available Bal  NGN18,854.81CR
# 32  Acct  7204    DR  NGN100.00    Desc  USSD/QT PYMT/Airtime Recharge on 2349032170930    DT  23/MAY/2021 18 57 15    Available Bal  NGN18,954.81CR
# 33  Acct  7204    CR  NGN1,000.00    Desc  SUCCESS   EREKWDOR/Bills    DT  01/JUN/2021 13 46 04    Available Bal  NGN4,744.06CR
# 34  Acct  7204    DR  NGN100.00    Desc  POS@3IPG0001/MSPORT_t1140393642i3650interswitchdeLANG    DT  22/MAY/2021 22 44 04    Available Bal  NGN19,054.81CR
# 35  Debit    Acct xxxxx94615    Amt N12,000.00    Ref USSD.BNKG 058/ADEYEMI ASHOLA O/F    Bal N50,329.43    27 05 202112 50    Enjoy 30days FREE transfers when you download VULTe app
# 36  Debit    Acct xxxxx94615    Amt N6,500.00    Ref USSD.BNKG 057/VICTORIA NSICAN BAS    Bal N43,775.68    27 05 202113 06    Enjoy 30days FREE transfers when you download VULTe app
# 37  Credit    Acct xxxxx94615    Amt N62,356.87    Ref 25/05 Neft  GTB LASG PAYROLL AD    Bal N62,387.18    25 05 202119 47    Enjoy 30days FREE transfers when you download VULTe app
# 38  Debit    Acct xxxxx94615    Amt N600.00    Ref USSD.BNKG 058/ADEYEMI ASHOLA O/FT TO  A    Bal N85.49    02 06 202117 43    Enjoy 30days FREE transfers when you download VULTe app
# 39  Credit!    Acct 603987    Amt N10,000.00    Desc UNIEDUSOKO14 NEFT TRF BO UNIED    Date 28 05 2021 15 18    Bal N11,068.62    DOWNLOAD APP bit.ly/31MJj1s
# 40  Debit!    Acct 603987    Amt N 10.00    Desc Charges   Balance enquiry char    Date 31 05 2021 22 37    Bal N1,029.10    DOWNLOAD APP bit.ly/31MJj1s
# 41  Debit!    Acct 603987    Amt N 10,000.00    Desc TRF IFO MUHAMMAD JIBRIN TSONFA    Date 30 05 2021 08 23    Bal N1,037.74    DOWNLOAD APP bit.ly/31MJj1s
# 42  Dear Abdullahi, Keystone Bank wishes you a Happy Birthday, may your day be an amazing and memorable one, Have a wonderful celebration!
# 43  Acct  8715    DR  NGN5,000.00    Desc  PYA@2TEPDB59/T De Kings          004357 2TEPDB59 LANG    DT  01/JUN/2021 15 50 04    Available Bal  NGN212,112.01CR
# 44  Debit NGN45,000.00    A/C 2628    NIP TRANSFER IFO SPICE OF LAGOS Interbank  REF  751    27 May 21    Bal NGN110,677.35    Don't share your bank details with anyone
# 45  Debit NGN23,000.00    A/C 2628    NIP TRANSFER IFO IJEOMA MARGARET OKOLINTA Interbank    28 May 21    Bal NGN87,650.47    Don't share your bank details with anyone
# 46
# 47
# 83  Wema Credit       NGN100,000.00       Acct No 023008       Desc.  NIP OLADIMEJI ADEMOLA JOHN FBNMOBILE MORUFU ALABI        Bal  463,510.71       31 05 2021 06 14
# 84  Acct  4380    DR  NGN100.00    Desc  AFM@20078586/WT BEST STEVE GLOBAL ENTE       BENIN NG    DT  24/MAY/2021 16 16 28    Available Bal  NGN19,628.38CR
# 85  Acct  4380    DR  NGN3,000.00    Desc  PYA@20078586/WT BEST STEVE GLOBAL ENTE       BENIN NG    DT  24/MAY/2021 16 16 28    Available Bal  NGN19,628.38CR
# 86  Credit NGN3,000.00    A/C 9073    NIP FROM OGUWIKE CHIMAOBI AUGUSTUS/FBNMOBILE IBEKWE    25 May 21    Bal NGN7,032.52    Don't share your bank details with anyone
# 87  Credit NGN20,000.00    A/C 9073    NIP FROM OGUWIKE CHIMAOBI AUGUSTUS/FBNMOBILE IBEKWE    26 May 21    Bal NGN21,982.52    Don't share your bank details with anyone
# 88  Acct  5164    DR  NGN20,000.00    Desc  Cash Withdrawal from UBN ATM10326091@GBOGAN RD1 OSHOGBO     OSHOGBO     DT  24/MAY/2021 15 36 02    Available Bal  NGN106,386.49CR
# 89  Acct  5164    DR  NGN20,000.00    Desc  Cash Withdrawal from UBN ATM10326091@GBOGAN RD1 OSHOGBO     OSHOGBO      DT  24/MAY/2021 15 39 15    Available Bal  NGN26,386.49CR
# 90  Acct  5164    DR  NGN20,000.00    Desc  Cash Withdrawal from UBN ATM10326091@GBOGAN RD1 OSHOGBO     OSHOGBO      DT  24/MAY/2021 15 36 50    Available Bal  NGN86,386.49CR
# 91  Acct  5164    DR  NGN20,000.00    Desc  Cash Withdrawal from UBN ATM10326091@GBOGAN RD1 OSHOGBO     OSHOGBO      DT  24/MAY/2021 15 37 39    Available Bal  NGN66,386.49CR
# 92  Acct  5164    CR  NGN5,000.00    Desc  ADEDOTUN HAMMED ADEOYE/ONB TRF FROM ADEDOTUN H 2462 FBP    DT  26/MAY/2021 17 26 50    Available Bal  NGN44,736.49CR
# 93  Acct  5164    DR  NGN6,150.00    Desc  PYA@2TEPY252/T ABLELUX GLOBAL CO 010395 2TEPY252 LANG    DT  19/MAY/2021 13 32 02    Available Bal  NGN8,254.49CR
# 94  Acct  5164    CR  NGN8,000.00    Desc  OLAYEMI PETER BANKOLE/NIP/ussd/IFT114413266523643898267441533    DT  26/MAY/2021 18 27 34    Available Bal  NGN52,736.49CR
# 95  Acct  5164    CR  NGN1,000.00    Desc  KAZEEM ADEDAYOR OLANIPEKUN/MOB/UTO/8096342950/000018/Market    DT  24/MAY/2021 20 44 20    Available Bal  NGN3,386.49CR
# 96  Acct  5164    CR  NGN5,000.00    Desc  KEHINDE TAOFEEK ADISA/MOB/UTO/8096523612/000018/AbleGod    DT  24/MAY/2021 21 02 36    Available Bal  NGN8,386.49CR
# 97  Acct  5164    CR  NGN20,000.00    Desc  DANIEL CHUKWUEMEKA EBERE/Cana    DT  23/MAY/2021 09 36 51    Available Bal  NGN114,436.49CR
# 98  Acct  5164    DR  NGN20,000.00    Desc  Cash Withdrawal from UBN ATM10326091@GBOGAN RD1 OSHOGBO     OSHOGBO       DT  24/MAY/2021 15 40 03    Available Bal  NGN6,386.49CR
# 99  Acct  5164    CR  NGN10,000.00    Desc  ADELEKE SERIFDEEN ADEBOLA/App transfer To Union Bank ISRAEL OLUWATIMI    DT  19/MAY/2021 15 17 24    Available Bal  NGN18,204.49CR
